# %% [markdown]
# 1. Configurando el proyecto
#
#     1.1 Creación del ambiente virtual
#
#     Se crea el ambiente virtual para establecer las librerías a utilizar para el proyecto. Desde el Terminal:
#
#     python -m venv venv

# %% [markdown]
# Importamos Librerías

# %%
import json 
import pandas as pd
import ast

# %%
# Lee el archivo JSON y carga los datos en un DataFrame
df = pd.read_json('data/australian_users_items.json')

# Ahora, 'df' es un DataFrame de pandas con los datos del archivo JSON
print(df)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\Anabel\Desktop\Henry_PI_1\PI_1_AJH\inicio_1.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Anabel/Desktop/Henry_PI_1/PI_1_AJH/inicio_1.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # Lee el archivo JSON y carga los datos en un DataFrame
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Anabel/Desktop/Henry_PI_1/PI_1_AJH/inicio_1.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_json('data/australian_users_items.json')
#       <a href='vscode-notebook-cell:/c%3A/Users/Anabel/Desktop/Henry_PI_1/PI_1_AJH/inicio_1.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> # Ahora, 'df' es un DataFrame de pandas con los datos del archivo JSON
#       <a href='vscode-notebook-cell:/c%3A/Users/Anabel/Desktop/Henry_PI_1/PI_1_AJH/inicio_1.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> print(df)
#
# ...

# %%
import json

# Abre el archivo en modo lectura
with open('data/australian_users_items.json', 'r') as file:
    # Lee cada línea y carga el contenido JSON
    for line in file:
        data = json.loads(line)
        
        # Ahora, 'data' contiene la información del objeto JSON en esa línea
        print(data)

# %%
# Primer archivo: australian_users_items

reviews = []
with open('data/australian_users_items.json', 'r', encoding='utf-8') as f:
    for line in f.readlines():
        reviews.append(ast.literal_eval(line))


df_user_items = pd.DataFrame(reviews)
df_user_items
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# ...
